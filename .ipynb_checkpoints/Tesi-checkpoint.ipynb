# %%
from keplergl import KeplerGl
import json
import networkx
import uuid

dataset_indicatori = json.load(open('Indicatori/ds385_popolazione_indicatori_popolazione_famiglie_2011_breve-1.json'))
dataset_censimento = json.load(open('Censimento_Milano_2011/sezioni_censimento_2011.geojson'))

#Data reorganization
list = []

for i in dataset_indicatori:
    obj = {}
    for j in i:
        index = j.split(')',1)[0]
        if (index == "2" or index == "3" or index == "4" or index == "9" or index == "14" or index == "15" or index == "18" or index == "26" or  index == "27" or index == "28" or index == "35" or index == "40" or index == "41"):
            if (i.get(j)!= None):
                obj[j.split(')',1)[0]] = i.get(j).replace(',','.')
            else:
                obj[j.split(')',1)[0]] = i.get(j)
        elif (index == "1"):
            obj["sez"] = i.get(j)
        else:
            continue
    list.append(obj)

#Data sorting
indicatori = {"legenda":["1) Numero medio di residenti per edificio ad uso residenziale","2) Numero medio di abitazioni per edificio ad uso residenziale",
"3) Numero medio di abitazioni occupate da residenti per edificio ad uso residenziale","8) Percentuale di bambini in età prescolare","13) Percentuale di abitazioni non occupate",
"14) Percentuale di famiglie monogenitore","17) Percentuale di 65+ che vivono da soli","25) Giovani (0-14 anni) ogni 100 in età attiva (15-64anni)",
"26) Over65 enni ogni 100 persone in età attiva (15-64 anni) ","27) Percentuale di popolazione 15+ che percepisce reddito sul totale della popolazione 15+",
"34) Percentuale di popolazione residente che si sposta giornalmente per studio o lavoro","39) Numero medio di componenti delle famiglie",
"40) Percentuale di famiglie di un componente"],"indicatori":[]}
for i in list:
    obj_2 = {}
    for j in range(2,45):
        if (i.get(str(j))== None):
            continue
        else:
            obj_2[j-1] = i.get(str(j))
    obj_2["sez"]=i.get("sez")
    indicatori.get("indicatori").append(obj_2)

temp = []
for i in dataset_censimento.get("features"): temp.append(i.get("properties").get("SEZ"))
temp = max(temp)
ordered = []

for i in range (0, temp+1):
    for j in dataset_censimento.get("features"):
        if (j.get("properties").get("SEZ") == i):
            ordered.append(j)

with open("Censimento_Milano_2011/censimento_cleared.geojson", 'x') as outfile:
    json.dump(dataset_censimento, outfile, indent=1)
with open("Indicatori/indicatori_cleared.json", 'x') as outfile:
    json.dump(indicatori, outfile, indent=1)

ordered_2 = []
for i in indicatori.get("indicatori"):
    for j in ordered:
        if (int(i.get("sez")) == int(j.get("properties").get("SEZ"))):
            j["indicatori"] = i
            ordered_2.append(j)
 
for i in ordered_2: i.get("indicatori").pop("sez")
dataset_censimento["features"] = ordered_2

with open("dataset_completo.geojson", 'x') as outfile:
    json.dump(dataset_censimento, outfile, indent=1)

# %%
censimento = json.load(open('dataset_completo.geojson'))
    
#Load Map config
# %run 'Censimento_Milano_2011/config.py'

map = KeplerGl(data={"censimento_milano_2011": censimento},config=config)
map
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'k75ulfp', 'type': …

# %%
#Sezione-based randomic family generator

settori = {}
id_familiare = 1

for i in censimento.get("features"):
    if (i.get("properties").get("POP_2010") == 0 or i.get("indicatori").get("1") == '' or i.get("indicatori").get("1") == "0"):
        continue
    print("Codice sezione:",i.get("properties").get("SEZ"))
    POP_2010 = i.get("properties").get("POP_2010")
    edifici = round(POP_2010/float(i.get("indicatori").get("1")))
    tot_appartamenti = round(edifici*float(i.get("indicatori").get("3")))
    print("Popolazione:",POP_2010)
    print("Numero di edifici ad uso residenziale:", edifici)
    print("Numero di abitazioni totali ad uso residenziale:", tot_appartamenti)
    if (tot_appartamenti!=0):
        avg_ppa = POP_2010/tot_appartamenti
        print("Numero di abitanti per appartamento ad uso residenziale:", avg_ppa)
        print("Numero medio di componenti delle famiglie:", i.get("indicatori").get("39"))
    #print("Percentuale di 65+ che vivono da soli:",i.get("indicatori").get("17"))
    #print("Percentuale di bambini in età prescolare:",i.get("indicatori").get("8"))

    #Percentuali esterne alla fascia 15-64
    if (i.get("indicatori").get("25") != '' and i.get("indicatori").get("26") != ''):
        young = float(i.get("indicatori").get("25"))
        old = float(i.get("indicatori").get("26"))
        Y = old + young

        X = (100+Y)/100
        mid_percent = 100/X
        old_percent = old/X
        young_percent = young/X

        anziani = round((POP_2010/100)*(old_percent))
        giovani = round((POP_2010/100)*(young_percent))
        attivi = round((POP_2010/100)*mid_percent)

        #Clone POP_2010 and households for counting purposes
        popolazione = POP_2010
        appartamenti = tot_appartamenti

        print("Abitanti nella fascia 15-64:", attivi)
        #print("Abitanti fuori dalla fascia 15-64:",anziani+giovani)
        print("Abitanti < 15:", giovani)
        print("Abitanti > 65:", anziani)
        print("Over 65+ che vivono da soli:",round(((round((POP_2010/100)*(old_percent)))/100*float(i.get("indicatori").get("27")))))
        print()

        #TODO: CHECK FOR MALFORMED INDICATORS
        if (i.get("properties").get("SEZ") == 54 or i.get("properties").get("SEZ") == 3233 or i.get("properties").get("SEZ") == 2785 or i.get("properties").get("SEZ") == 2842 or i.get("properties").get("SEZ") == 2873 or i.get("properties").get("SEZ") == 3042 or i.get("properties").get("SEZ") == 3581 or i.get("properties").get("SEZ") == 4145 or i.get("properties").get("SEZ") == 4339 or i.get("properties").get("SEZ") == 4797 or i.get("properties").get("SEZ") == 4982 or i.get("properties").get("SEZ") == 5669):
            continue

        settore = []

        #65+ old solo families generator
        for j in range (0,round(((round((POP_2010/100)*(old_percent)))/100*float(i.get("indicatori").get("27"))))):
            fam = {}
            members = []
            obj = {}
            obj["uuid"] = str(uuid.uuid4())
            obj["age"] = "old"
            fam["family_id"] = id_familiare
            members.append(obj)
            fam["members"] = members
            id_familiare = id_familiare + 1
            anziani = anziani - 1
            settore.append(fam)

        #Remove created families from 65+
        popolazione = popolazione - round(((round((POP_2010/100)*(old_percent)))/100*float(i.get("indicatori").get("27"))))
        appartamenti = appartamenti - round(((round((POP_2010/100)*(old_percent)))/100*float(i.get("indicatori").get("27"))))

        #Families with children one parent generator
        if (i.get("indicatori").get("14") != "0"):
            max_fam = (giovani/100)*float(i.get("indicatori").get("14"))
            num = round(max_fam/avg_ppa)
            #NUM = Number of families with one parent
            for k in range (0,num):

                #Members removal code
                kids_number = round(max_fam/num)
                max_fam = max_fam - kids_number
                POP_2010 = POP_2010 - (kids_number + 1)
                giovani = giovani - kids_number 
                fam = {}
                members = []
                obj = {}
                obj["uuid"] = str(uuid.uuid4())
                obj["age"] = "active"
                members.append(obj)

                for kid in range(0,kids_number):
                    obj = {}
                    obj["uuid"] = str(uuid.uuid4())
                    obj["age"] = "kid"
                    members.append(obj)

                fam["family_id"] = id_familiare
                fam["members"] = members
                id_familiare = id_familiare + 1

                attivi = attivi - num
                popolazione = popolazione - len(fam.get("members"))
                settore.append(fam)

        if (giovani != 0):
            #Max families members / mean familiy size
            max_componenti = round(giovani*3)
            avg_fam = round(max_componenti/avg_ppa)

            if (avg_fam > giovani):
                num = giovani
            else:
                num = avg_fam

            #NUM = Number of families with two parents
            mean_kpf = round(giovani/num)
            for k in range(0,num):
                
                fam = {}
                members = []

                #Add parents
                for parent in range(0,2):
                    obj = {}
                    obj["uuid"] = str(uuid.uuid4())
                    obj["age"] = "mid"
                    members.append(obj)

                if (giovani < mean_kpf):
                    kids = giovani
                else: 
                    kids = mean_kpf

                for kid in range(0,kids):
                    obj = {}
                    obj["uuid"] = str(uuid.uuid4())
                    obj["age"] = "kid"
                    members.append(obj)
                
                POP_2010 = POP_2010 - (2+kids)
                giovani = giovani - kids
                attivi = attivi - 2

                fam["family_id"] = id_familiare
                fam["members"] = members
                id_familiare = id_familiare + 1
                appartamenti = appartamenti - 1 
                popolazione = popolazione - len(fam.get("members"))
                settore.append(fam)


        #Generate remaining families
        #65+ families
        for index in range (0, round(anziani/2)):
            fam = {}
            members = []

            if (anziani == 1):
                #1 old, 1 mid
                obj = {}
                obj["uuid"] = str(uuid.uuid4())
                obj["age"] = "old"
                members.append(obj)
                obj = {}
                obj["uuid"] = str(uuid.uuid4())
                obj["age"] = "mid"
                members.append(obj)
                anziani = anziani - 1
                attivi = attivi - 1
            else:
                #2 old
                for parent in range(0,2):
                    obj = {}
                    obj["uuid"] = str(uuid.uuid4())
                    obj["age"] = "old"
                    members.append(obj)
                anziani = anziani - 2

            fam["family_id"] = id_familiare
            fam["members"] = members
            id_familiare = id_familiare + 1
            appartamenti = appartamenti - 1 
            popolazione = popolazione - len(fam.get("members"))
            settore.append(fam)

        #Active families
        for index in range (0, round(attivi/2)):
            fam = {}
            members = []

            if (attivi == 1):
                obj = {}
                obj["uuid"] = str(uuid.uuid4())
                obj["age"] = "mid"
                members.append(obj)
                attivi = attivi - 1
            else:
                #2 old
                for parent in range(0,2):
                    obj = {}
                    obj["uuid"] = str(uuid.uuid4())
                    obj["age"] = "mid"
                    members.append(obj)
                attivi = attivi - 2

            fam["family_id"] = id_familiare
            fam["members"] = members
            id_familiare = id_familiare + 1
            appartamenti = appartamenti - 1
            popolazione = popolazione - len(fam.get("members")) 
            settore.append(fam)
        
        settori[i.get("properties").get("SEZ")] = {"ace":i.get("properties").get("ACE"),"families":settore}
# Out:
# vivono da soli: 4
#
# Codice sezione: 6041
# Popolazione: 434.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 194
# Numero di abitanti per appartamento ad uso residenziale: 2.2371134020618557
# Numero medio di componenti delle famiglie: 2.41
# Abitanti nella fascia 15-64: 305
# Abitanti < 15: 86
# Abitanti > 65: 43
# Over 65+ che vivono da soli: 5
#
# Codice sezione: 6042
# Popolazione: 593.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 196
# Numero di abitanti per appartamento ad uso residenziale: 3.0255102040816326
# Numero medio di componenti delle famiglie: 2.97
# Abitanti nella fascia 15-64: 441
# Abitanti < 15: 92
# Abitanti > 65: 60
# Over 65+ che vivono da soli: 8
#
# Codice sezione: 6043
# Popolazione: 83.0
# Numero di edifici ad uso residenziale: 8
# Numero di abitazioni totali ad uso residenziale: 35
# Numero di abitanti per appartamento ad uso residenziale: 2.3714285714285714
# Numero medio di componenti delle famiglie: 2.07
# Abitanti nella fascia 15-64: 66
# Abitanti < 15: 11
# Abitanti > 65: 6
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6044
# Popolazione: 219.0
# Numero di edifici ad uso residenziale: 7
# Numero di abitazioni totali ad uso residenziale: 100
# Numero di abitanti per appartamento ad uso residenziale: 2.19
# Numero medio di componenti delle famiglie: 2.09
# Abitanti nella fascia 15-64: 165
# Abitanti < 15: 42
# Abitanti > 65: 12
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6045
# Popolazione: 19.0
# Numero di edifici ad uso residenziale: 1
# Numero di abitazioni totali ad uso residenziale: 6
# Numero di abitanti per appartamento ad uso residenziale: 3.1666666666666665
# Numero medio di componenti delle famiglie: 2.17
# Abitanti nella fascia 15-64: 12
# Abitanti < 15: 4
# Abitanti > 65: 2
# Over 65+ che vivono da soli: 0
#
# Codice sezione: 6046
# Popolazione: 2.0
# Numero di edifici ad uso residenziale: 0
# Numero di abitazioni totali ad uso residenziale: 0
# Abitanti nella fascia 15-64: 2
# Abitanti < 15: 0
# Abitanti > 65: 0
# Over 65+ che vivono da soli: 0
#
# Codice sezione: 6047
# Popolazione: 605.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 236
# Numero di abitanti per appartamento ad uso residenziale: 2.5635593220338984
# Numero medio di componenti delle famiglie: 2.58
# Abitanti nella fascia 15-64: 448
# Abitanti < 15: 124
# Abitanti > 65: 33
# Over 65+ che vivono da soli: 3
#
# Codice sezione: 6048
# Popolazione: 22.0
# Numero di edifici ad uso residenziale: 0
# Numero di abitazioni totali ad uso residenziale: 0
# Abitanti nella fascia 15-64: 17
# Abitanti < 15: 4
# Abitanti > 65: 1
# Over 65+ che vivono da soli: 0
#
# Codice sezione: 6049
# Popolazione: 595.0
# Numero di edifici ad uso residenziale: 8
# Numero di abitazioni totali ad uso residenziale: 262
# Numero di abitanti per appartamento ad uso residenziale: 2.2709923664122136
# Numero medio di componenti delle famiglie: 2.3
# Abitanti nella fascia 15-64: 446
# Abitanti < 15: 96
# Abitanti > 65: 53
# Over 65+ che vivono da soli: 7
#
# Codice sezione: 6050
# Popolazione: 261.0
# Numero di edifici ad uso residenziale: 11
# Numero di abitazioni totali ad uso residenziale: 143
# Numero di abitanti per appartamento ad uso residenziale: 1.8251748251748252
# Numero medio di componenti delle famiglie: 1.86
# Abitanti nella fascia 15-64: 155
# Abitanti < 15: 23
# Abitanti > 65: 83
# Over 65+ che vivono da soli: 28
#
# Codice sezione: 6051
# Popolazione: 417.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 166
# Numero di abitanti per appartamento ad uso residenziale: 2.5120481927710845
# Numero medio di componenti delle famiglie: 2.37
# Abitanti nella fascia 15-64: 319
# Abitanti < 15: 56
# Abitanti > 65: 42
# Over 65+ che vivono da soli: 6
#
# Codice sezione: 6052
# Popolazione: 41.0
# Numero di edifici ad uso residenziale: 2
# Numero di abitazioni totali ad uso residenziale: 16
# Numero di abitanti per appartamento ad uso residenziale: 2.5625
# Numero medio di componenti delle famiglie: 2.31
# Abitanti nella fascia 15-64: 29
# Abitanti < 15: 9
# Abitanti > 65: 3
# Over 65+ che vivono da soli: 0
#
# Codice sezione: 6055
# Popolazione: 238.0
# Numero di edifici ad uso residenziale: 2
# Numero di abitazioni totali ad uso residenziale: 115
# Numero di abitanti per appartamento ad uso residenziale: 2.0695652173913044
# Numero medio di componenti delle famiglie: 2.18
# Abitanti nella fascia 15-64: 175
# Abitanti < 15: 46
# Abitanti > 65: 18
# Over 65+ che vivono da soli: 2
#
# Codice sezione: 6057
# Popolazione: 223.0
# Numero di edifici ad uso residenziale: 1
# Numero di abitazioni totali ad uso residenziale: 90
# Numero di abitanti per appartamento ad uso residenziale: 2.477777777777778
# Numero medio di componenti delle famiglie: 2.27
# Abitanti nella fascia 15-64: 172
# Abitanti < 15: 24
# Abitanti > 65: 27
# Over 65+ che vivono da soli: 5
#
# Codice sezione: 6058
# Popolazione: 309.0
# Numero di edifici ad uso residenziale: 2
# Numero di abitazioni totali ad uso residenziale: 188
# Numero di abitanti per appartamento ad uso residenziale: 1.6436170212765957
# Numero medio di componenti delle famiglie: 1.8
# Abitanti nella fascia 15-64: 249
# Abitanti < 15: 46
# Abitanti > 65: 14
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6059
# Popolazione: 599.0
# Numero di edifici ad uso residenziale: 7
# Numero di abitazioni totali ad uso residenziale: 243
# Numero di abitanti per appartamento ad uso residenziale: 2.4650205761316872
# Numero medio di componenti delle famiglie: 2.29
# Abitanti nella fascia 15-64: 426
# Abitanti < 15: 104
# Abitanti > 65: 69
# Over 65+ che vivono da soli: 9
#
# Codice sezione: 6060
# Popolazione: 508.0
# Numero di edifici ad uso residenziale: 2
# Numero di abitazioni totali ad uso residenziale: 197
# Numero di abitanti per appartamento ad uso residenziale: 2.5786802030456855
# Numero medio di componenti delle famiglie: 2.39
# Abitanti nella fascia 15-64: 363
# Abitanti < 15: 84
# Abitanti > 65: 61
# Over 65+ che vivono da soli: 9
#
# Codice sezione: 6064
# Popolazione: 221.0
# Numero di edifici ad uso residenziale: 1
# Numero di abitazioni totali ad uso residenziale: 88
# Numero di abitanti per appartamento ad uso residenziale: 2.5113636363636362
# Numero medio di componenti delle famiglie: 2.38
# Abitanti nella fascia 15-64: 170
# Abitanti < 15: 26
# Abitanti > 65: 24
# Over 65+ che vivono da soli: 4
#
# Codice sezione: 6065
# Popolazione: 1.0
# Numero di edifici ad uso residenziale: 1
# Numero di abitazioni totali ad uso residenziale: 1
# Numero di abitanti per appartamento ad uso residenziale: 1.0
# Numero medio di componenti delle famiglie: 1
# Codice sezione: 6066
# Popolazione: 135.0
# Numero di edifici ad uso residenziale: 18
# Numero di abitazioni totali ad uso residenziale: 66
# Numero di abitanti per appartamento ad uso residenziale: 2.0454545454545454
# Numero medio di componenti delle famiglie: 1.91
# Abitanti nella fascia 15-64: 101
# Abitanti < 15: 13
# Abitanti > 65: 21
# Over 65+ che vivono da soli: 3
#
# Codice sezione: 6067
# Popolazione: 622.0
# Numero di edifici ad uso residenziale: 8
# Numero di abitazioni totali ad uso residenziale: 216
# Numero di abitanti per appartamento ad uso residenziale: 2.8796296296296298
# Numero medio di componenti delle famiglie: 2.77
# Abitanti nella fascia 15-64: 460
# Abitanti < 15: 99
# Abitanti > 65: 63
# Over 65+ che vivono da soli: 8
#
# Codice sezione: 6068
# Popolazione: 310.0
# Numero di edifici ad uso residenziale: 5
# Numero di abitazioni totali ad uso residenziale: 119
# Numero di abitanti per appartamento ad uso residenziale: 2.6050420168067228
# Numero medio di componenti delle famiglie: 2.5
# Abitanti nella fascia 15-64: 221
# Abitanti < 15: 55
# Abitanti > 65: 34
# Over 65+ che vivono da soli: 5
#
# Codice sezione: 6069
# Popolazione: 476.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 170
# Numero di abitanti per appartamento ad uso residenziale: 2.8
# Numero medio di componenti delle famiglie: 2.84
# Abitanti nella fascia 15-64: 346
# Abitanti < 15: 92
# Abitanti > 65: 38
# Over 65+ che vivono da soli: 4
#
# Codice sezione: 6070
# Popolazione: 522.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 229
# Numero di abitanti per appartamento ad uso residenziale: 2.2794759825327513
# Numero medio di componenti delle famiglie: 2.35
# Abitanti nella fascia 15-64: 417
# Abitanti < 15: 90
# Abitanti > 65: 14
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6071
# Popolazione: 264.0
# Numero di edifici ad uso residenziale: 1
# Numero di abitazioni totali ad uso residenziale: 109
# Numero di abitanti per appartamento ad uso residenziale: 2.4220183486238533
# Numero medio di componenti delle famiglie: 2.33
# Abitanti nella fascia 15-64: 192
# Abitanti < 15: 48
# Abitanti > 65: 24
# Over 65+ che vivono da soli: 3
#
# Codice sezione: 6072
# Popolazione: 680.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 271
# Numero di abitanti per appartamento ad uso residenziale: 2.5092250922509227
# Numero medio di componenti delle famiglie: 2.41
# Abitanti nella fascia 15-64: 499
# Abitanti < 15: 122
# Abitanti > 65: 59
# Over 65+ che vivono da soli: 7
#
# Codice sezione: 6073
# Popolazione: 701.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 307
# Numero di abitanti per appartamento ad uso residenziale: 2.2833876221498373
# Numero medio di componenti delle famiglie: 2.17
# Abitanti nella fascia 15-64: 523
# Abitanti < 15: 123
# Abitanti > 65: 56
# Over 65+ che vivono da soli: 6
#
# Codice sezione: 6075
# Popolazione: 54.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 28
# Numero di abitanti per appartamento ad uso residenziale: 1.9285714285714286
# Numero medio di componenti delle famiglie: 1.82
# Abitanti nella fascia 15-64: 41
# Abitanti < 15: 5
# Abitanti > 65: 7
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6076
# Popolazione: 142.0
# Numero di edifici ad uso residenziale: 1
# Numero di abitazioni totali ad uso residenziale: 71
# Numero di abitanti per appartamento ad uso residenziale: 2.0
# Numero medio di componenti delle famiglie: 2
# Abitanti nella fascia 15-64: 109
# Abitanti < 15: 16
# Abitanti > 65: 17
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6077
# Popolazione: 429.0
# Numero di edifici ad uso residenziale: 11
# Numero di abitazioni totali ad uso residenziale: 153
# Numero di abitanti per appartamento ad uso residenziale: 2.803921568627451
# Numero medio di componenti delle famiglie: 2.66
# Abitanti nella fascia 15-64: 317
# Abitanti < 15: 87
# Abitanti > 65: 25
# Over 65+ che vivono da soli: 2
#
# Codice sezione: 6078
# Popolazione: 314.0
# Numero di edifici ad uso residenziale: 5
# Numero di abitazioni totali ad uso residenziale: 117
# Numero di abitanti per appartamento ad uso residenziale: 2.6837606837606836
# Numero medio di componenti delle famiglie: 2.68
# Abitanti nella fascia 15-64: 255
# Abitanti < 15: 44
# Abitanti > 65: 15
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6079
# Popolazione: 276.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 129
# Numero di abitanti per appartamento ad uso residenziale: 2.13953488372093
# Numero medio di componenti delle famiglie: 1.98
# Abitanti nella fascia 15-64: 154
# Abitanti < 15: 24
# Abitanti > 65: 98
# Over 65+ che vivono da soli: 33
#
# Codice sezione: 6080
# Popolazione: 362.0
# Numero di edifici ad uso residenziale: 12
# Numero di abitazioni totali ad uso residenziale: 165
# Numero di abitanti per appartamento ad uso residenziale: 2.193939393939394
# Numero medio di componenti delle famiglie: 2.06
# Abitanti nella fascia 15-64: 282
# Abitanti < 15: 54
# Abitanti > 65: 26
# Over 65+ che vivono da soli: 3
#
# Codice sezione: 6081
# Popolazione: 604.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 244
# Numero di abitanti per appartamento ad uso residenziale: 2.4754098360655736
# Numero medio di componenti delle famiglie: 2.55
# Abitanti nella fascia 15-64: 421
# Abitanti < 15: 80
# Abitanti > 65: 102
# Over 65+ che vivono da soli: 20
#
# Codice sezione: 6082
# Popolazione: 607.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 267
# Numero di abitanti per appartamento ad uso residenziale: 2.2734082397003745
# Numero medio di componenti delle famiglie: 2.24
# Abitanti nella fascia 15-64: 446
# Abitanti < 15: 116
# Abitanti > 65: 45
# Over 65+ che vivono da soli: 5
#
# Codice sezione: 6083
# Popolazione: 138.0
# Numero di edifici ad uso residenziale: 2
# Numero di abitazioni totali ad uso residenziale: 52
# Numero di abitanti per appartamento ad uso residenziale: 2.6538461538461537
# Numero medio di componenti delle famiglie: 2.31
# Abitanti nella fascia 15-64: 92
# Abitanti < 15: 15
# Abitanti > 65: 31
# Over 65+ che vivono da soli: 7
#
# Codice sezione: 6084
# Popolazione: 373.0
# Numero di edifici ad uso residenziale: 5
# Numero di abitazioni totali ad uso residenziale: 154
# Numero di abitanti per appartamento ad uso residenziale: 2.4220779220779223
# Numero medio di componenti delle famiglie: 2.3
# Abitanti nella fascia 15-64: 251
# Abitanti < 15: 32
# Abitanti > 65: 89
# Over 65+ che vivono da soli: 24
#
# Codice sezione: 6085
# Popolazione: 630.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 279
# Numero di abitanti per appartamento ad uso residenziale: 2.2580645161290325
# Numero medio di componenti delle famiglie: 2.25
# Abitanti nella fascia 15-64: 472
# Abitanti < 15: 115
# Abitanti > 65: 43
# Over 65+ che vivono da soli: 4
#
# Codice sezione: 6086
# Popolazione: 643.0
# Numero di edifici ad uso residenziale: 7
# Numero di abitazioni totali ad uso residenziale: 244
# Numero di abitanti per appartamento ad uso residenziale: 2.6352459016393444
# Numero medio di componenti delle famiglie: 2.55
# Abitanti nella fascia 15-64: 488
# Abitanti < 15: 123
# Abitanti > 65: 32
# Over 65+ che vivono da soli: 3
#
# Codice sezione: 6087
# Popolazione: 163.0
# Numero di edifici ad uso residenziale: 2
# Numero di abitazioni totali ad uso residenziale: 59
# Numero di abitanti per appartamento ad uso residenziale: 2.76271186440678
# Numero medio di componenti delle famiglie: 2.63
# Abitanti nella fascia 15-64: 113
# Abitanti < 15: 41
# Abitanti > 65: 9
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6088
# Popolazione: 448.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 206
# Numero di abitanti per appartamento ad uso residenziale: 2.174757281553398
# Numero medio di componenti delle famiglie: 2.28
# Abitanti nella fascia 15-64: 322
# Abitanti < 15: 96
# Abitanti > 65: 30
# Over 65+ che vivono da soli: 2
#
# Codice sezione: 6090
# Popolazione: 107.0
# Numero di edifici ad uso residenziale: 1
# Numero di abitazioni totali ad uso residenziale: 71
# Numero di abitanti per appartamento ad uso residenziale: 1.5070422535211268
# Numero medio di componenti delle famiglie: 2.18
# Abitanti nella fascia 15-64: 82
# Abitanti < 15: 18
# Abitanti > 65: 8
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6091
# Popolazione: 230.0
# Numero di edifici ad uso residenziale: 2
# Numero di abitazioni totali ad uso residenziale: 99
# Numero di abitanti per appartamento ad uso residenziale: 2.323232323232323
# Numero medio di componenti delle famiglie: 2.1
# Abitanti nella fascia 15-64: 177
# Abitanti < 15: 43
# Abitanti > 65: 10
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6092
# Popolazione: 286.0
# Numero di edifici ad uso residenziale: 1
# Numero di abitazioni totali ad uso residenziale: 120
# Numero di abitanti per appartamento ad uso residenziale: 2.3833333333333333
# Numero medio di componenti delle famiglie: 1.89
# Abitanti nella fascia 15-64: 222
# Abitanti < 15: 51
# Abitanti > 65: 13
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6093
# Popolazione: 237.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 118
# Numero di abitanti per appartamento ad uso residenziale: 2.0084745762711864
# Numero medio di componenti delle famiglie: 1.9
# Abitanti nella fascia 15-64: 189
# Abitanti < 15: 31
# Abitanti > 65: 17
# Over 65+ che vivono da soli: 2
#
# Codice sezione: 6094
# Popolazione: 506.0
# Numero di edifici ad uso residenziale: 9
# Numero di abitazioni totali ad uso residenziale: 284
# Numero di abitanti per appartamento ad uso residenziale: 1.7816901408450705
# Numero medio di componenti delle famiglie: 1.86
# Abitanti nella fascia 15-64: 403
# Abitanti < 15: 84
# Abitanti > 65: 19
# Over 65+ che vivono da soli: 1
#
# Codice sezione: 6095
# Popolazione: 314.0
# Numero di edifici ad uso residenziale: 3
# Numero di abitazioni totali ad uso residenziale: 127
# Numero di abitanti per appartamento ad uso residenziale: 2.47244094488189
# Numero medio di componenti delle famiglie: 2.22
# Abitanti nella fascia 15-64: 236
# Abitanti < 15: 55
# Abitanti > 65: 23
# Over 65+ che vivono da soli: 3
#
# Codice sezione: 6096
# Popolazione: 584.0
# Numero di edifici ad uso residenziale: 8
# Numero di abitazioni totali ad uso residenziale: 229
# Numero di abitanti per appartamento ad uso residenziale: 2.550218340611354
# Numero medio di componenti delle famiglie: 2.43
# Abitanti nella fascia 15-64: 448
# Abitanti < 15: 96
# Abitanti > 65: 39
# Over 65+ che vivono da soli: 4
#
# Codice sezione: 6098
# Popolazione: 695.0
# Numero di edifici ad uso residenziale: 34
# Numero di abitazioni totali ad uso residenziale: 340
# Numero di abitanti per appartamento ad uso residenziale: 2.0441176470588234
# Numero medio di componenti delle famiglie: 2.01
# Abitanti nella fascia 15-64: 510
# Abitanti < 15: 57
# Abitanti > 65: 128
# Over 65+ che vivono da soli: 28
#
# Codice sezione: 6099
# Popolazione: 722.0
# Numero di edifici ad uso residenziale: 13
# Numero di abitazioni totali ad uso residenziale: 295
# Numero di abitanti per appartamento ad uso residenziale: 2.447457627118644
# Numero medio di componenti delle famiglie: 2.51
# Abitanti nella fascia 15-64: 537
# Abitanti < 15: 143
# Abitanti > 65: 42
# Over 65+ che vivono da soli: 4
#
# Codice sezione: 6100
# Popolazione: 664.0
# Numero di edifici ad uso residenziale: 11
# Numero di abitazioni totali ad uso residenziale: 278
# Numero di abitanti per appartamento ad uso residenziale: 2.3884892086330933
# Numero medio di componenti delle famiglie: 2.39
# Abitanti nella fascia 15-64: 492
# Abitanti < 15: 121
# Abitanti > 65: 51
# Over 65+ che vivono da soli: 5
#
# Codice sezione: 6101
# Popolazione: 69.0
# Numero di edifici ad uso residenziale: 2
# Numero di abitazioni totali ad uso residenziale: 34
# Numero di abitanti per appartamento ad uso residenziale: 2.0294117647058822
# Numero medio di componenti delle famiglie: 2.04
# Abitanti nella fascia 15-64: 51
# Abitanti < 15: 13
# Abitanti > 65: 5
# Over 65+ che vivono da soli: 0
#
# Codice sezione: 6102
# Popolazione: 305.0
# Numero di edifici ad uso residenziale: 15
# Numero di abitazioni totali ad uso residenziale: 167
# Numero di abitanti per appartamento ad uso residenziale: 1.8263473053892216
# Numero medio di componenti delle famiglie: 1.85
# Abitanti nella fascia 15-64: 177
# Abitanti < 15: 20
# Abitanti > 65: 108
# Over 65+ che vivono da soli: 37
#
# Codice sezione: 6103
# Popolazione: 1063.0
# Numero di edifici ad uso residenziale: 20
# Numero di abitazioni totali ad uso residenziale: 353
# Numero di abitanti per appartamento ad uso residenziale: 3.011331444759207
# Numero medio di componenti delle famiglie: 3.06
# Abitanti nella fascia 15-64: 791
# Abitanti < 15: 183
# Abitanti > 65: 90
# Over 65+ che vivono da soli: 10
#
# Codice sezione: 6105
# Popolazione: 489.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 175
# Numero di abitanti per appartamento ad uso residenziale: 2.7942857142857145
# Numero medio di componenti delle famiglie: 2.58
# Abitanti nella fascia 15-64: 379
# Abitanti < 15: 47
# Abitanti > 65: 62
# Over 65+ che vivono da soli: 10
#
# Codice sezione: 6106
# Popolazione: 492.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 182
# Numero di abitanti per appartamento ad uso residenziale: 2.7032967032967035
# Numero medio di componenti delle famiglie: 2.53
# Abitanti nella fascia 15-64: 408
# Abitanti < 15: 39
# Abitanti > 65: 45
# Over 65+ che vivono da soli: 6
#
# Codice sezione: 6107
# Popolazione: 342.0
# Numero di edifici ad uso residenziale: 4
# Numero di abitazioni totali ad uso residenziale: 144
# Numero di abitanti per appartamento ad uso residenziale: 2.375
# Numero medio di componenti delle famiglie: 2.64
# Abitanti nella fascia 15-64: 262
# Abitanti < 15: 53
# Abitanti > 65: 27
# Over 65+ che vivono da soli: 2

# %%
with open("household_layer.json", 'x') as outfile:
    json.dump(settori, outfile, indent=1)
